# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uw-geophysics-edu/ess314/blob/main/notebooks/Lab4-Reflection.ipynb)

# %% [markdown]
# # Lab 4: Reflection
#
# **ESS 314 — Introduction to Geophysics**
#
# ## Learning Objectives
# - Process seismic reflection data (CMP, NMO, stacking)
# - Interpret reflection profiles
# - Relate reflectors to geological boundaries

# %%
import numpy as np
import matplotlib.pyplot as plt
