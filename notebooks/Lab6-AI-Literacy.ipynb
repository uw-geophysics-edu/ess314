# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uw-geophysics-edu/ess314/blob/main/notebooks/Lab6-AI-Literacy.ipynb)

# %% [markdown]
# # Lab 6: AI Literacy
#
# **ESS 314 — Introduction to Geophysics** *(remote / async)*
#
# ## Learning Objectives
# - Understand how AI and machine learning tools are used in geophysics
# - Critically evaluate AI-generated scientific content
# - Explore ethical considerations of AI in Earth science

# %%
import numpy as np
import matplotlib.pyplot as plt
