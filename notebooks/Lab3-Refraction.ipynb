# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uw-geophysics-edu/ess314/blob/main/notebooks/Lab3-Refraction.ipynb)

# %% [markdown]
# # Lab 3: Refraction
#
# **ESS 314 — Introduction to Geophysics**
#
# ## Learning Objectives
# - Analyze refraction survey data
# - Determine layer velocities and thicknesses from travel-time plots
# - Interpret subsurface structure from refraction results

# %%
import numpy as np
import matplotlib.pyplot as plt
