# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uw-geophysics-edu/ess314/blob/main/notebooks/Lab2-Python-Ray-Tracing.ipynb)

# %% [markdown]
# # Lab 2: Intro to Python II and Seismic Ray Tracing
#
# **ESS 314 — Introduction to Geophysics**
#
# ## Learning Objectives
# - Deepen Python skills (arrays, loops, plotting)
# - Implement basic seismic ray tracing
# - Visualize ray paths through layered media

# %%
import numpy as np
import matplotlib.pyplot as plt
