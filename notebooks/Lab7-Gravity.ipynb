# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uw-geophysics-edu/ess314/blob/main/notebooks/Lab7-Gravity.ipynb)

# %% [markdown]
# # Lab 7: Gravity
#
# **ESS 314 — Introduction to Geophysics**
#
# ## Learning Objectives
# - Compute gravity corrections (free-air, Bouguer)
# - Interpret gravity anomaly profiles
# - Model subsurface density structure from gravity data

# %%
import numpy as np
import matplotlib.pyplot as plt
