# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uw-geophysics-edu/ess314/blob/main/notebooks/Lab8-Magnetics.ipynb)

# %% [markdown]
# # Lab 8: Magnetics
#
# **ESS 314 — Introduction to Geophysics**
#
# ## Learning Objectives
# - Analyze magnetic anomaly data
# - Relate magnetic anomalies to geological structures
# - Interpret magnetic stripes and seafloor spreading

# %%
import numpy as np
import matplotlib.pyplot as plt
