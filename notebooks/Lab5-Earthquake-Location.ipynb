# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uw-geophysics-edu/ess314/blob/main/notebooks/Lab5-Earthquake-Location.ipynb)

# %% [markdown]
# # Lab 5: Earthquake Location
#
# **ESS 314 — Introduction to Geophysics**
#
# ## Learning Objectives
# - Locate earthquakes using P and S arrival times
# - Understand trilateration and least-squares location methods
# - Assess location uncertainties

# %%
import numpy as np
import matplotlib.pyplot as plt
